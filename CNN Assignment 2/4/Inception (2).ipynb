# %% [markdown]
# ## Inception/GoogleNet implementation with Keras

# %%
# !nvidia-smi
# Out:
# Sun Aug  1 04:13:07 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### 1. Import libraries

# %%
import cv2 
import numpy as np 
import keras
import math
from keras.layers.core import Layer
import keras.backend as K
import tensorflow as tf
from keras.datasets import cifar10
from keras.models import Model
from keras.layers import Conv2D, MaxPool2D,  \
    Dropout, Dense, Input, concatenate,      \
    GlobalAveragePooling2D, AveragePooling2D,\
    Flatten
from keras.datasets import cifar10 
from keras import backend as K 
from keras.utils import np_utils 
from keras.optimizers import SGD 
from keras.callbacks import LearningRateScheduler

# %% [markdown]
# ### 2. Prepare the dataset

# %%
num_classes = 10

def load_cifar10_data(img_rows, img_cols):

    # Load cifar10 training and validation sets
    (X_train, Y_train), (X_valid, Y_valid) = cifar10.load_data()

    # Resize training images
    X_train = np.array([cv2.resize(img, (img_rows,img_cols)) for img in X_train[:,:,:,:]])
    X_valid = np.array([cv2.resize(img, (img_rows,img_cols)) for img in X_valid[:,:,:,:]])

    # Transform targets to keras compatible format
    Y_train = np_utils.to_categorical(Y_train, num_classes)
    Y_valid = np_utils.to_categorical(Y_valid, num_classes)
    
    X_train = X_train.astype('float32')
    X_valid = X_valid.astype('float32')

    # preprocess data
    X_train = X_train / 255.0
    X_valid = X_valid / 255.0

    return X_train, Y_train, X_valid, Y_valid

# %%
X_train, y_train, X_test, y_test = load_cifar10_data(32,32)

# %%
def inception_module(x,
                     filters_1x1,
                     filters_3x3_reduce,
                     filters_3x3,
                     filters_5x5_reduce,
                     filters_5x5,
                     filters_pool_proj,
                     name=None):
    
    conv_1x1 = Conv2D(filters_1x1, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    
    conv_3x3 = Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    conv_3x3 = Conv2D(filters_3x3, (3, 3), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(conv_3x3)

    conv_5x5 = Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    conv_5x5 = Conv2D(filters_5x5, (5, 5), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(conv_5x5)

    pool_proj = MaxPool2D((3, 3), strides=(1, 1), padding='same')(x)
    pool_proj = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(pool_proj)

    output = concatenate([conv_1x1, conv_3x3, conv_5x5, pool_proj], axis=3, name=name)
    
    return output

# %% [markdown]
# ### 4. Create the GoogLeNet architecture

# %%
kernel_init = keras.initializers.glorot_uniform()
bias_init = keras.initializers.Constant(value=0.2)

# %%
##change start
input_layer = Input(shape=(32, 32, 3))
resized_images = keras.layers.Lambda(lambda image: tf.image.resize(image, (224, 224)))(input_layer)
x = Conv2D(64, (7, 7), padding='same', strides=(2, 2), activation='relu', name='conv_1_7x7/2', kernel_initializer=kernel_init, bias_initializer=bias_init)(resized_images)

##change ends
x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_1_3x3/2')(x)
# x = Conv2D(64, (1, 1), padding='same', strides=(1, 1), activation='relu', name='conv_2a_3x3/1')(x)
x = Conv2D(192, (3, 3), padding='same', strides=(1, 1), activation='relu', name='conv_2b_3x3/1')(x)
x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_2_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=64,
                     filters_3x3_reduce=96,
                     filters_3x3=128,
                     filters_5x5_reduce=16,
                     filters_5x5=32,
                     filters_pool_proj=32,
                     name='inception_3a')

x = inception_module(x,
                     filters_1x1=128,
                     filters_3x3_reduce=128,
                     filters_3x3=192,
                     filters_5x5_reduce=32,
                     filters_5x5=96,
                     filters_pool_proj=64,
                     name='inception_3b')

x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_3_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=192,
                     filters_3x3_reduce=96,
                     filters_3x3=208,
                     filters_5x5_reduce=16,
                     filters_5x5=48,
                     filters_pool_proj=64,
                     name='inception_4a')


classifier_1 = AveragePooling2D((5, 5), strides=3)(x)
classifier_1 = Conv2D(128, (1, 1), padding='same', activation='relu')(classifier_1)
classifier_1 = Flatten()(classifier_1)
classifier_1 = Dense(1024, activation='relu')(classifier_1)
classifier_1 = Dropout(0.7)(classifier_1)
classifier_1 = Dense(10, activation='softmax', name='auxilliary_output_1')(classifier_1)

x = inception_module(x,
                     filters_1x1=160,
                     filters_3x3_reduce=112,
                     filters_3x3=224,
                     filters_5x5_reduce=24,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4b')

x = inception_module(x,
                     filters_1x1=128,
                     filters_3x3_reduce=128,
                     filters_3x3=256,
                     filters_5x5_reduce=24,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4c')

x = inception_module(x,
                     filters_1x1=112,
                     filters_3x3_reduce=144,
                     filters_3x3=288,
                     filters_5x5_reduce=32,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4d')


classifier_2 = AveragePooling2D((5, 5), strides=3)(x)
classifier_2 = Conv2D(128, (1, 1), padding='same', activation='relu')(classifier_2)
classifier_2 = Flatten()(classifier_2)
classifier_2 = Dense(1024, activation='relu')(classifier_2)
classifier_2 = Dropout(0.7)(classifier_2)
classifier_2 = Dense(10, activation='softmax', name='auxilliary_output_2')(classifier_2)

x = inception_module(x,
                     filters_1x1=256,
                     filters_3x3_reduce=160,
                     filters_3x3=320,
                     filters_5x5_reduce=32,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_4e')

x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_4_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=256,
                     filters_3x3_reduce=160,
                     filters_3x3=320,
                     filters_5x5_reduce=32,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_5a')

x = inception_module(x,
                     filters_1x1=384,
                     filters_3x3_reduce=192,
                     filters_3x3=384,
                     filters_5x5_reduce=48,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_5b')

x = AveragePooling2D(pool_size=(7,7), strides=1, padding='valid',name='avg_pool_5_3x3/1')(x)

x = Dropout(0.4)(x)
x = Dense(10, activation='relu', name='linear')(x)
x = Dense(10, activation='softmax', name='output')(x)

# %% [markdown]
# ### GoogleNet model without the classfiers 1 and 2

# %%
model = Model(input_layer, [x], name='googlenet')

# %%
model.summary()
# Out:
# Model: "googlenet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 224, 224, 3)  0           input_8[0][0]
# __________________________________________________________________________________________________
# conv_1_7x7/2 (Conv2D)           (None, 112, 112, 64) 9472        lambda_5[0][0]
# __________________________________________________________________________________________________
# max_pool_1_3x3/2 (MaxPooling2D) (None, 56, 56, 64)   0           conv_1_7x7/2[0][0]
# __________________________________________________________________________________________________
# conv_2b_3x3/1 (Conv2D)          (None, 56, 56, 192)  110784      max_pool_1_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pool_2_3x3/2 (MaxPooling2D) (None, 28, 28, 192)  0           conv_2b_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 28, 28, 96)   18528       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 28, 28, 16)   3088        max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_36 (MaxPooling2D) (None, 28, 28, 192)  0           max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 28, 28, 64)   12352       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, 28, 28, 128)  110720      conv2d_225[0][0]
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 28, 28, 32)   12832       conv2d_227[0][0]
# __________________________________________________________________________________________________
# conv2d_229 (Conv2D)             (None, 28, 28, 32)   6176        max_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# inception_3a (Concatenate)      (None, 28, 28, 256)  0           conv2d_224[0][0]
#                                                                  conv2d_226[0][0]
#                                                                  conv2d_228[0][0]
#                                                                  conv2d_229[0][0]
# __________________________________________________________________________________________________
# conv2d_231 (Conv2D)             (None, 28, 28, 128)  32896       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_233 (Conv2D)             (None, 28, 28, 32)   8224        inception_3a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_37 (MaxPooling2D) (None, 28, 28, 256)  0           inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_230 (Conv2D)             (None, 28, 28, 128)  32896       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_232 (Conv2D)             (None, 28, 28, 192)  221376      conv2d_231[0][0]
# __________________________________________________________________________________________________
# conv2d_234 (Conv2D)             (None, 28, 28, 96)   76896       conv2d_233[0][0]
# __________________________________________________________________________________________________
# conv2d_235 (Conv2D)             (None, 28, 28, 64)   16448       max_pooling2d_37[0][0]
# __________________________________________________________________________________________________
# inception_3b (Concatenate)      (None, 28, 28, 480)  0           conv2d_230[0][0]
#                                                                  conv2d_232[0][0]
#                                                                  conv2d_234[0][0]
#                                                                  conv2d_235[0][0]
# __________________________________________________________________________________________________
# max_pool_3_3x3/2 (MaxPooling2D) (None, 14, 14, 480)  0           inception_3b[0][0]
# __________________________________________________________________________________________________
# conv2d_237 (Conv2D)             (None, 14, 14, 96)   46176       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_239 (Conv2D)             (None, 14, 14, 16)   7696        max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_38 (MaxPooling2D) (None, 14, 14, 480)  0           max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_236 (Conv2D)             (None, 14, 14, 192)  92352       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_238 (Conv2D)             (None, 14, 14, 208)  179920      conv2d_237[0][0]
# __________________________________________________________________________________________________
# conv2d_240 (Conv2D)             (None, 14, 14, 48)   19248       conv2d_239[0][0]
# __________________________________________________________________________________________________
# conv2d_241 (Conv2D)             (None, 14, 14, 64)   30784       max_pooling2d_38[0][0]
# __________________________________________________________________________________________________
# inception_4a (Concatenate)      (None, 14, 14, 512)  0           conv2d_236[0][0]
#                                                                  conv2d_238[0][0]
#                                                                  conv2d_240[0][0]
#                                                                  conv2d_241[0][0]
# __________________________________________________________________________________________________
# conv2d_244 (Conv2D)             (None, 14, 14, 112)  57456       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_246 (Conv2D)             (None, 14, 14, 24)   12312       inception_4a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_39 (MaxPooling2D) (None, 14, 14, 512)  0           inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_243 (Conv2D)             (None, 14, 14, 160)  82080       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_245 (Conv2D)             (None, 14, 14, 224)  226016      conv2d_244[0][0]
# __________________________________________________________________________________________________
# conv2d_247 (Conv2D)             (None, 14, 14, 64)   38464       conv2d_246[0][0]
# __________________________________________________________________________________________________
# conv2d_248 (Conv2D)             (None, 14, 14, 64)   32832       max_pooling2d_39[0][0]
# __________________________________________________________________________________________________
# inception_4b (Concatenate)      (None, 14, 14, 512)  0           conv2d_243[0][0]
#                                                                  conv2d_245[0][0]
#                                                                  conv2d_247[0][0]
#                                                                  conv2d_248[0][0]
# __________________________________________________________________________________________________
# conv2d_250 (Conv2D)             (None, 14, 14, 128)  65664       inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_252 (Conv2D)             (None, 14, 14, 24)   12312       inception_4b[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_40 (MaxPooling2D) (None, 14, 14, 512)  0           inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_249 (Conv2D)             (None, 14, 14, 128)  65664       inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_251 (Conv2D)             (None, 14, 14, 256)  295168      conv2d_250[0][0]
# __________________________________________________________________________________________________
# conv2d_253 (Conv2D)             (None, 14, 14, 64)   38464       conv2d_252[0][0]
# __________________________________________________________________________________________________
# conv2d_254 (Conv2D)             (None, 14, 14, 64)   32832       max_pooling2d_40[0][0]
# __________________________________________________________________________________________________
# inception_4c (Concatenate)      (None, 14, 14, 512)  0           conv2d_249[0][0]
#                                                                  conv2d_251[0][0]
#                                                                  conv2d_253[0][0]
#                                                                  conv2d_254[0][0]
# __________________________________________________________________________________________________
# conv2d_256 (Conv2D)             (None, 14, 14, 144)  73872       inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_258 (Conv2D)             (None, 14, 14, 32)   16416       inception_4c[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_41 (MaxPooling2D) (None, 14, 14, 512)  0           inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_255 (Conv2D)             (None, 14, 14, 112)  57456       inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_257 (Conv2D)             (None, 14, 14, 288)  373536      conv2d_256[0][0]
# __________________________________________________________________________________________________
# conv2d_259 (Conv2D)             (None, 14, 14, 64)   51264       conv2d_258[0][0]
# __________________________________________________________________________________________________
# conv2d_260 (Conv2D)             (None, 14, 14, 64)   32832       max_pooling2d_41[0][0]
# __________________________________________________________________________________________________
# inception_4d (Concatenate)      (None, 14, 14, 528)  0           conv2d_255[0][0]
#                                                                  conv2d_257[0][0]
#                                                                  conv2d_259[0][0]
#                                                                  conv2d_260[0][0]
# __________________________________________________________________________________________________
# conv2d_263 (Conv2D)             (None, 14, 14, 160)  84640       inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_265 (Conv2D)             (None, 14, 14, 32)   16928       inception_4d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_42 (MaxPooling2D) (None, 14, 14, 528)  0           inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_262 (Conv2D)             (None, 14, 14, 256)  135424      inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_264 (Conv2D)             (None, 14, 14, 320)  461120      conv2d_263[0][0]
# __________________________________________________________________________________________________
# conv2d_266 (Conv2D)             (None, 14, 14, 128)  102528      conv2d_265[0][0]
# __________________________________________________________________________________________________
# conv2d_267 (Conv2D)             (None, 14, 14, 128)  67712       max_pooling2d_42[0][0]
# __________________________________________________________________________________________________
# inception_4e (Concatenate)      (None, 14, 14, 832)  0           conv2d_262[0][0]
#                                                                  conv2d_264[0][0]
#                                                                  conv2d_266[0][0]
#                                                                  conv2d_267[0][0]
# __________________________________________________________________________________________________
# max_pool_4_3x3/2 (MaxPooling2D) (None, 7, 7, 832)    0           inception_4e[0][0]
# __________________________________________________________________________________________________
# conv2d_269 (Conv2D)             (None, 7, 7, 160)    133280      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_271 (Conv2D)             (None, 7, 7, 32)     26656       max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_43 (MaxPooling2D) (None, 7, 7, 832)    0           max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_268 (Conv2D)             (None, 7, 7, 256)    213248      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_270 (Conv2D)             (None, 7, 7, 320)    461120      conv2d_269[0][0]
# __________________________________________________________________________________________________
# conv2d_272 (Conv2D)             (None, 7, 7, 128)    102528      conv2d_271[0][0]
# __________________________________________________________________________________________________
# conv2d_273 (Conv2D)             (None, 7, 7, 128)    106624      max_pooling2d_43[0][0]
# __________________________________________________________________________________________________
# inception_5a (Concatenate)      (None, 7, 7, 832)    0           conv2d_268[0][0]
#                                                                  conv2d_270[0][0]
#                                                                  conv2d_272[0][0]
#                                                                  conv2d_273[0][0]
# __________________________________________________________________________________________________
# conv2d_275 (Conv2D)             (None, 7, 7, 192)    159936      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_277 (Conv2D)             (None, 7, 7, 48)     39984       inception_5a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_44 (MaxPooling2D) (None, 7, 7, 832)    0           inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_274 (Conv2D)             (None, 7, 7, 384)    319872      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_276 (Conv2D)             (None, 7, 7, 384)    663936      conv2d_275[0][0]
# __________________________________________________________________________________________________
# conv2d_278 (Conv2D)             (None, 7, 7, 128)    153728      conv2d_277[0][0]
# __________________________________________________________________________________________________
# conv2d_279 (Conv2D)             (None, 7, 7, 128)    106624      max_pooling2d_44[0][0]
# __________________________________________________________________________________________________
# inception_5b (Concatenate)      (None, 7, 7, 1024)   0           conv2d_274[0][0]
#                                                                  conv2d_276[0][0]
#                                                                  conv2d_278[0][0]
#                                                                  conv2d_279[0][0]
# __________________________________________________________________________________________________
# avg_pool_5_3x3/1 (AveragePoolin (None, 1, 1, 1024)   0           inception_5b[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 1, 1, 1024)   0           avg_pool_5_3x3/1[0][0]
# __________________________________________________________________________________________________
# linear (Dense)                  (None, 1, 1, 10)     10250       dropout_14[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1, 1, 10)     110         linear[0][0]
# ==================================================================================================
# Total params: 5,979,752
# Trainable params: 5,979,752
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### GoogLeNet model after adding classifiers 1 and 2

# %%
model_with_classifiers = Model(input_layer, [x, classifier_1, classifier_2], name='googlenet_complete_architecture')
model_with_classifiers.summary()
# Out:
# Model: "googlenet_complete_architecture"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 224, 224, 3)  0           input_8[0][0]
# __________________________________________________________________________________________________
# conv_1_7x7/2 (Conv2D)           (None, 112, 112, 64) 9472        lambda_5[0][0]
# __________________________________________________________________________________________________
# max_pool_1_3x3/2 (MaxPooling2D) (None, 56, 56, 64)   0           conv_1_7x7/2[0][0]
# __________________________________________________________________________________________________
# conv_2b_3x3/1 (Conv2D)          (None, 56, 56, 192)  110784      max_pool_1_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pool_2_3x3/2 (MaxPooling2D) (None, 28, 28, 192)  0           conv_2b_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 28, 28, 96)   18528       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 28, 28, 16)   3088        max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_36 (MaxPooling2D) (None, 28, 28, 192)  0           max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 28, 28, 64)   12352       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, 28, 28, 128)  110720      conv2d_225[0][0]
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 28, 28, 32)   12832       conv2d_227[0][0]
# __________________________________________________________________________________________________
# conv2d_229 (Conv2D)             (None, 28, 28, 32)   6176        max_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# inception_3a (Concatenate)      (None, 28, 28, 256)  0           conv2d_224[0][0]
#                                                                  conv2d_226[0][0]
#                                                                  conv2d_228[0][0]
#                                                                  conv2d_229[0][0]
# __________________________________________________________________________________________________
# conv2d_231 (Conv2D)             (None, 28, 28, 128)  32896       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_233 (Conv2D)             (None, 28, 28, 32)   8224        inception_3a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_37 (MaxPooling2D) (None, 28, 28, 256)  0           inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_230 (Conv2D)             (None, 28, 28, 128)  32896       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_232 (Conv2D)             (None, 28, 28, 192)  221376      conv2d_231[0][0]
# __________________________________________________________________________________________________
# conv2d_234 (Conv2D)             (None, 28, 28, 96)   76896       conv2d_233[0][0]
# __________________________________________________________________________________________________
# conv2d_235 (Conv2D)             (None, 28, 28, 64)   16448       max_pooling2d_37[0][0]
# __________________________________________________________________________________________________
# inception_3b (Concatenate)      (None, 28, 28, 480)  0           conv2d_230[0][0]
#                                                                  conv2d_232[0][0]
#                                                                  conv2d_234[0][0]
#                                                                  conv2d_235[0][0]
# __________________________________________________________________________________________________
# max_pool_3_3x3/2 (MaxPooling2D) (None, 14, 14, 480)  0           inception_3b[0][0]
# __________________________________________________________________________________________________
# conv2d_237 (Conv2D)             (None, 14, 14, 96)   46176       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_239 (Conv2D)             (None, 14, 14, 16)   7696        max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_38 (MaxPooling2D) (None, 14, 14, 480)  0           max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_236 (Conv2D)             (None, 14, 14, 192)  92352       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_238 (Conv2D)             (None, 14, 14, 208)  179920      conv2d_237[0][0]
# __________________________________________________________________________________________________
# conv2d_240 (Conv2D)             (None, 14, 14, 48)   19248       conv2d_239[0][0]
# __________________________________________________________________________________________________
# conv2d_241 (Conv2D)             (None, 14, 14, 64)   30784       max_pooling2d_38[0][0]
# __________________________________________________________________________________________________
# inception_4a (Concatenate)      (None, 14, 14, 512)  0           conv2d_236[0][0]
#                                                                  conv2d_238[0][0]
#                                                                  conv2d_240[0][0]
#                                                                  conv2d_241[0][0]
# __________________________________________________________________________________________________
# conv2d_244 (Conv2D)             (None, 14, 14, 112)  57456       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_246 (Conv2D)             (None, 14, 14, 24)   12312       inception_4a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_39 (MaxPooling2D) (None, 14, 14, 512)  0           inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_243 (Conv2D)             (None, 14, 14, 160)  82080       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_245 (Conv2D)             (None, 14, 14, 224)  226016      conv2d_244[0][0]
# __________________________________________________________________________________________________
# conv2d_247 (Conv2D)             (None, 14, 14, 64)   38464       conv2d_246[0][0]
# __________________________________________________________________________________________________
# conv2d_248 (Conv2D)             (None, 14, 14, 64)   32832       max_pooling2d_39[0][0]
# __________________________________________________________________________________________________
# inception_4b (Concatenate)      (None, 14, 14, 512)  0           conv2d_243[0][0]
#                                                                  conv2d_245[0][0]
#                                                                  conv2d_247[0][0]
#                                                                  conv2d_248[0][0]
# __________________________________________________________________________________________________
# conv2d_250 (Conv2D)             (None, 14, 14, 128)  65664       inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_252 (Conv2D)             (None, 14, 14, 24)   12312       inception_4b[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_40 (MaxPooling2D) (None, 14, 14, 512)  0           inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_249 (Conv2D)             (None, 14, 14, 128)  65664       inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_251 (Conv2D)             (None, 14, 14, 256)  295168      conv2d_250[0][0]
# __________________________________________________________________________________________________
# conv2d_253 (Conv2D)             (None, 14, 14, 64)   38464       conv2d_252[0][0]
# __________________________________________________________________________________________________
# conv2d_254 (Conv2D)             (None, 14, 14, 64)   32832       max_pooling2d_40[0][0]
# __________________________________________________________________________________________________
# inception_4c (Concatenate)      (None, 14, 14, 512)  0           conv2d_249[0][0]
#                                                                  conv2d_251[0][0]
#                                                                  conv2d_253[0][0]
#                                                                  conv2d_254[0][0]
# __________________________________________________________________________________________________
# conv2d_256 (Conv2D)             (None, 14, 14, 144)  73872       inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_258 (Conv2D)             (None, 14, 14, 32)   16416       inception_4c[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_41 (MaxPooling2D) (None, 14, 14, 512)  0           inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_255 (Conv2D)             (None, 14, 14, 112)  57456       inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_257 (Conv2D)             (None, 14, 14, 288)  373536      conv2d_256[0][0]
# __________________________________________________________________________________________________
# conv2d_259 (Conv2D)             (None, 14, 14, 64)   51264       conv2d_258[0][0]
# __________________________________________________________________________________________________
# conv2d_260 (Conv2D)             (None, 14, 14, 64)   32832       max_pooling2d_41[0][0]
# __________________________________________________________________________________________________
# inception_4d (Concatenate)      (None, 14, 14, 528)  0           conv2d_255[0][0]
#                                                                  conv2d_257[0][0]
#                                                                  conv2d_259[0][0]
#                                                                  conv2d_260[0][0]
# __________________________________________________________________________________________________
# conv2d_263 (Conv2D)             (None, 14, 14, 160)  84640       inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_265 (Conv2D)             (None, 14, 14, 32)   16928       inception_4d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_42 (MaxPooling2D) (None, 14, 14, 528)  0           inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_262 (Conv2D)             (None, 14, 14, 256)  135424      inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_264 (Conv2D)             (None, 14, 14, 320)  461120      conv2d_263[0][0]
# __________________________________________________________________________________________________
# conv2d_266 (Conv2D)             (None, 14, 14, 128)  102528      conv2d_265[0][0]
# __________________________________________________________________________________________________
# conv2d_267 (Conv2D)             (None, 14, 14, 128)  67712       max_pooling2d_42[0][0]
# __________________________________________________________________________________________________
# inception_4e (Concatenate)      (None, 14, 14, 832)  0           conv2d_262[0][0]
#                                                                  conv2d_264[0][0]
#                                                                  conv2d_266[0][0]
#                                                                  conv2d_267[0][0]
# __________________________________________________________________________________________________
# max_pool_4_3x3/2 (MaxPooling2D) (None, 7, 7, 832)    0           inception_4e[0][0]
# __________________________________________________________________________________________________
# conv2d_269 (Conv2D)             (None, 7, 7, 160)    133280      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_271 (Conv2D)             (None, 7, 7, 32)     26656       max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_43 (MaxPooling2D) (None, 7, 7, 832)    0           max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_268 (Conv2D)             (None, 7, 7, 256)    213248      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_270 (Conv2D)             (None, 7, 7, 320)    461120      conv2d_269[0][0]
# __________________________________________________________________________________________________
# conv2d_272 (Conv2D)             (None, 7, 7, 128)    102528      conv2d_271[0][0]
# __________________________________________________________________________________________________
# conv2d_273 (Conv2D)             (None, 7, 7, 128)    106624      max_pooling2d_43[0][0]
# __________________________________________________________________________________________________
# inception_5a (Concatenate)      (None, 7, 7, 832)    0           conv2d_268[0][0]
#                                                                  conv2d_270[0][0]
#                                                                  conv2d_272[0][0]
#                                                                  conv2d_273[0][0]
# __________________________________________________________________________________________________
# conv2d_275 (Conv2D)             (None, 7, 7, 192)    159936      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_277 (Conv2D)             (None, 7, 7, 48)     39984       inception_5a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_44 (MaxPooling2D) (None, 7, 7, 832)    0           inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_274 (Conv2D)             (None, 7, 7, 384)    319872      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_276 (Conv2D)             (None, 7, 7, 384)    663936      conv2d_275[0][0]
# __________________________________________________________________________________________________
# conv2d_278 (Conv2D)             (None, 7, 7, 128)    153728      conv2d_277[0][0]
# __________________________________________________________________________________________________
# conv2d_279 (Conv2D)             (None, 7, 7, 128)    106624      max_pooling2d_44[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 4, 4, 512)    0           inception_4a[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 4, 4, 528)    0           inception_4d[0][0]
# __________________________________________________________________________________________________
# inception_5b (Concatenate)      (None, 7, 7, 1024)   0           conv2d_274[0][0]
#                                                                  conv2d_276[0][0]
#                                                                  conv2d_278[0][0]
#                                                                  conv2d_279[0][0]
# __________________________________________________________________________________________________
# conv2d_242 (Conv2D)             (None, 4, 4, 128)    65664       average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_261 (Conv2D)             (None, 4, 4, 128)    67712       average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# avg_pool_5_3x3/1 (AveragePoolin (None, 1, 1, 1024)   0           inception_5b[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 2048)         0           conv2d_242[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 2048)         0           conv2d_261[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 1, 1, 1024)   0           avg_pool_5_3x3/1[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1024)         2098176     flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1024)         2098176     flatten_9[0][0]
# __________________________________________________________________________________________________
# linear (Dense)                  (None, 1, 1, 10)     10250       dropout_14[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 1024)         0           dense_8[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 1024)         0           dense_9[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1, 1, 10)     110         linear[0][0]
# __________________________________________________________________________________________________
# auxilliary_output_1 (Dense)     (None, 10)           10250       dropout_12[0][0]
# __________________________________________________________________________________________________
# auxilliary_output_2 (Dense)     (None, 10)           10250       dropout_13[0][0]
# ==================================================================================================
# Total params: 10,329,980
# Trainable params: 10,329,980
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### compile a network with three models

# %%
epochs = 25
initial_lrate = 0.01

def decay(epoch, steps=100):
    initial_lrate = 0.01
    drop = 0.96
    epochs_drop = 8
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

sgd = SGD(lr=initial_lrate, momentum=0.9, nesterov=False)

lr_sc = LearningRateScheduler(decay, verbose=1)

# model_with_classifiers.compile(loss=['categorical_crossentropy', 'categorical_crossentropy', 'categorical_crossentropy'], 
#               loss_weights=[1, 0.3, 0.3], optimizer=sgd, metrics=['accuracy'])
model_with_classifiers.compile(loss='mse', 
               optimizer=sgd, metrics=['accuracy'])

# history = model_with_classifiers.fit(X_train, [y_train, y_train, y_train], validation_data=(X_test, [y_test, y_test, y_test]), 
#                     epochs=epochs, batch_size=32, callbacks=[lr_sc])
history = model_with_classifiers.fit(X_train, y_train, validation_data=(X_test, y_test), 
                    epochs=epochs, batch_size=32, callbacks=[lr_sc])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/25
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.01.
# 1563/1563 [==============================] - 238s 125ms/step - loss: 0.2697 - output_loss: 0.0901 - auxilliary_output_1_loss: 0.0896 - auxilliary_output_2_loss: 0.0900 - output_accuracy: 0.0695 - auxilliary_output_1_accuracy: 0.1347 - auxilliary_output_2_accuracy: 0.1222 - val_loss: 0.2577 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0836 - val_auxilliary_output_2_loss: 0.0841 - val_output_accuracy: 0.0000e+00 - val_auxilliary_output_1_accuracy: 0.2681 - val_auxilliary_output_2_accuracy: 0.2574
# Epoch 2/25
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.01.
# 1563/1563 [==============================] - 191s 122ms/step - loss: 0.2584 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0841 - auxilliary_output_2_loss: 0.0843 - output_accuracy: 0.0159 - auxilliary_output_1_accuracy: 0.2489 - auxilliary_output_2_accuracy: 0.2416 - val_loss: 0.2469 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0783 - val_auxilliary_output_2_loss: 0.0785 - val_output_accuracy: 0.1000 - val_auxilliary_output_1_accuracy: 0.3537 - val_auxilliary_output_2_accuracy: 0.3525
# Epoch 3/25
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.01.
# 1563/1563 [==============================] - 200s 128ms/step - loss: 0.2487 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0792 - auxilliary_output_2_loss: 0.0795 - output_accuracy: 0.0274 - auxilliary_output_1_accuracy: 0.3323 - auxilliary_output_2_accuracy: 0.3271 - val_loss: 0.2371 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0734 - val_auxilliary_output_2_loss: 0.0737 - val_output_accuracy: 0.0000e+00 - val_auxilliary_output_1_accuracy: 0.4030 - val_auxilliary_output_2_accuracy: 0.3980
# Epoch 4/25
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.01.
# 1563/1563 [==============================] - 192s 123ms/step - loss: 0.2405 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0753 - auxilliary_output_2_loss: 0.0753 - output_accuracy: 0.0087 - auxilliary_output_1_accuracy: 0.3763 - auxilliary_output_2_accuracy: 0.3758 - val_loss: 0.2299 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0700 - val_auxilliary_output_2_loss: 0.0699 - val_output_accuracy: 0.1000 - val_auxilliary_output_1_accuracy: 0.4349 - val_auxilliary_output_2_accuracy: 0.4425
# Epoch 5/25
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.01.
# 1563/1563 [==============================] - 192s 123ms/step - loss: 0.2341 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0721 - auxilliary_output_2_loss: 0.0720 - output_accuracy: 0.0381 - auxilliary_output_1_accuracy: 0.4130 - auxilliary_output_2_accuracy: 0.4132 - val_loss: 0.2257 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0678 - val_auxilliary_output_2_loss: 0.0679 - val_output_accuracy: 0.0000e+00 - val_auxilliary_output_1_accuracy: 0.4572 - val_auxilliary_output_2_accuracy: 0.4503
# Epoch 6/25
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.01.
# 1563/1563 [==============================] - 192s 123ms/step - loss: 0.2291 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0698 - auxilliary_output_2_loss: 0.0693 - output_accuracy: 0.7664 - auxilliary_output_1_accuracy: 0.4379 - auxilliary_output_2_accuracy: 0.4425 - val_loss: 0.2199 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0653 - val_auxilliary_output_2_loss: 0.0646 - val_output_accuracy: 0.0000e+00 - val_auxilliary_output_1_accuracy: 0.4850 - val_auxilliary_output_2_accuracy: 0.4906
# Epoch 7/25
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.01.
# 1563/1563 [==============================] - 191s 123ms/step - loss: 0.2233 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0670 - auxilliary_output_2_loss: 0.0663 - output_accuracy: 0.0424 - auxilliary_output_1_accuracy: 0.4664 - auxilliary_output_2_accuracy: 0.4735 - val_loss: 0.2141 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0620 - val_auxilliary_output_2_loss: 0.0621 - val_output_accuracy: 0.0000e+00 - val_auxilliary_output_1_accuracy: 0.5106 - val_auxilliary_output_2_accuracy: 0.5098
# Epoch 8/25
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0096.
# 1563/1563 [==============================] - 192s 123ms/step - loss: 0.2183 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0647 - auxilliary_output_2_loss: 0.0636 - output_accuracy: 0.0284 - auxilliary_output_1_accuracy: 0.4874 - auxilliary_output_2_accuracy: 0.4985 - val_loss: 0.2084 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0599 - val_auxilliary_output_2_loss: 0.0585 - val_output_accuracy: 0.0000e+00 - val_auxilliary_output_1_accuracy: 0.5373 - val_auxilliary_output_2_accuracy: 0.5475
# Epoch 9/25
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0096.
# 1563/1563 [==============================] - 192s 123ms/step - loss: 0.2115 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0615 - auxilliary_output_2_loss: 0.0599 - output_accuracy: 0.0223 - auxilliary_output_1_accuracy: 0.5216 - auxilliary_output_2_accuracy: 0.5346 - val_loss: 0.2020 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0568 - val_auxilliary_output_2_loss: 0.0552 - val_output_accuracy: 0.0000e+00 - val_auxilliary_output_1_accuracy: 0.5612 - val_auxilliary_output_2_accuracy: 0.5722
# Epoch 10/25
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0096.
# 1563/1563 [==============================] - 192s 123ms/step - loss: 0.2057 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0589 - auxilliary_output_2_loss: 0.0568 - output_accuracy: 0.0604 - auxilliary_output_1_accuracy: 0.5474 - auxilliary_output_2_accuracy: 0.5643 - val_loss: 0.1955 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0535 - val_auxilliary_output_2_loss: 0.0520 - val_output_accuracy: 0.9000 - val_auxilliary_output_1_accuracy: 0.5958 - val_auxilliary_output_2_accuracy: 0.6056
# Epoch 11/25
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0096.
# 1563/1563 [==============================] - 192s 123ms/step - loss: 0.2007 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0564 - auxilliary_output_2_loss: 0.0543 - output_accuracy: 0.2716 - auxilliary_output_1_accuracy: 0.5658 - auxilliary_output_2_accuracy: 0.5862 - val_loss: 0.1939 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0527 - val_auxilliary_output_2_loss: 0.0512 - val_output_accuracy: 0.0000e+00 - val_auxilliary_output_1_accuracy: 0.6036 - val_auxilliary_output_2_accuracy: 0.6178
# Epoch 12/25
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0096.
# 1563/1563 [==============================] - 191s 122ms/step - loss: 0.1963 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0543 - auxilliary_output_2_loss: 0.0520 - output_accuracy: 0.2332 - auxilliary_output_1_accuracy: 0.5860 - auxilliary_output_2_accuracy: 0.6056 - val_loss: 0.1917 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0514 - val_auxilliary_output_2_loss: 0.0504 - val_output_accuracy: 0.0000e+00 - val_auxilliary_output_1_accuracy: 0.6095 - val_auxilliary_output_2_accuracy: 0.6183
# Epoch 13/25
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0096.
# 1563/1563 [==============================] - 191s 122ms/step - loss: 0.1907 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0514 - auxilliary_output_2_loss: 0.0493 - output_accuracy: 0.1950 - auxilliary_output_1_accuracy: 0.6111 - auxilliary_output_2_accuracy: 0.6277 - val_loss: 0.1823 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0470 - val_auxilliary_output_2_loss: 0.0453 - val_output_accuracy: 0.0000e+00 - val_auxilliary_output_1_accuracy: 0.6493 - val_auxilliary_output_2_accuracy: 0.6646
# Epoch 14/25
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0096.
# 1563/1563 [==============================] - 200s 128ms/step - loss: 0.1869 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0497 - auxilliary_output_2_loss: 0.0472 - output_accuracy: 0.0366 - auxilliary_output_1_accuracy: 0.6275 - auxilliary_output_2_accuracy: 0.6464 - val_loss: 0.1856 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0488 - val_auxilliary_output_2_loss: 0.0468 - val_output_accuracy: 0.1000 - val_auxilliary_output_1_accuracy: 0.6382 - val_auxilliary_output_2_accuracy: 0.6524
# Epoch 15/25
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0096.
# 1563/1563 [==============================] - 191s 122ms/step - loss: 0.1829 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0476 - auxilliary_output_2_loss: 0.0453 - output_accuracy: 0.0284 - auxilliary_output_1_accuracy: 0.6446 - auxilliary_output_2_accuracy: 0.6615 - val_loss: 0.1783 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0453 - val_auxilliary_output_2_loss: 0.0430 - val_output_accuracy: 0.1000 - val_auxilliary_output_1_accuracy: 0.6688 - val_auxilliary_output_2_accuracy: 0.6856
# Epoch 16/25
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.009216.
# 1563/1563 [==============================] - 191s 122ms/step - loss: 0.1788 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0457 - auxilliary_output_2_loss: 0.0431 - output_accuracy: 0.0064 - auxilliary_output_1_accuracy: 0.6594 - auxilliary_output_2_accuracy: 0.6845 - val_loss: 0.1784 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0451 - val_auxilliary_output_2_loss: 0.0433 - val_output_accuracy: 0.1000 - val_auxilliary_output_1_accuracy: 0.6676 - val_auxilliary_output_2_accuracy: 0.6831
# Epoch 17/25
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.009216.
# 1563/1563 [==============================] - 191s 122ms/step - loss: 0.1759 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0445 - auxilliary_output_2_loss: 0.0414 - output_accuracy: 0.2052 - auxilliary_output_1_accuracy: 0.6704 - auxilliary_output_2_accuracy: 0.6923 - val_loss: 0.1768 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0436 - val_auxilliary_output_2_loss: 0.0433 - val_output_accuracy: 0.1000 - val_auxilliary_output_1_accuracy: 0.6776 - val_auxilliary_output_2_accuracy: 0.6736
# Epoch 18/25
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.009216.
# 1563/1563 [==============================] - 191s 123ms/step - loss: 0.1725 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0428 - auxilliary_output_2_loss: 0.0397 - output_accuracy: 0.2695 - auxilliary_output_1_accuracy: 0.6840 - auxilliary_output_2_accuracy: 0.7096 - val_loss: 0.1696 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0408 - val_auxilliary_output_2_loss: 0.0388 - val_output_accuracy: 0.0000e+00 - val_auxilliary_output_1_accuracy: 0.6977 - val_auxilliary_output_2_accuracy: 0.7164
# Epoch 19/25
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.009216.
# 1563/1563 [==============================] - 192s 123ms/step - loss: 0.1701 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0418 - auxilliary_output_2_loss: 0.0384 - output_accuracy: 0.2449 - auxilliary_output_1_accuracy: 0.6926 - auxilliary_output_2_accuracy: 0.7217 - val_loss: 0.1659 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0389 - val_auxilliary_output_2_loss: 0.0370 - val_output_accuracy: 0.0000e+00 - val_auxilliary_output_1_accuracy: 0.7177 - val_auxilliary_output_2_accuracy: 0.7308
# Epoch 20/25
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.009216.
# 1563/1563 [==============================] - 201s 128ms/step - loss: 0.1678 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0402 - auxilliary_output_2_loss: 0.0376 - output_accuracy: 0.0080 - auxilliary_output_1_accuracy: 0.7064 - auxilliary_output_2_accuracy: 0.7282 - val_loss: 0.1647 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0381 - val_auxilliary_output_2_loss: 0.0366 - val_output_accuracy: 0.9000 - val_auxilliary_output_1_accuracy: 0.7239 - val_auxilliary_output_2_accuracy: 0.7345
# Epoch 21/25
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.009216.
# 1563/1563 [==============================] - 192s 123ms/step - loss: 0.1648 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0389 - auxilliary_output_2_loss: 0.0359 - output_accuracy: 0.3851 - auxilliary_output_1_accuracy: 0.7168 - auxilliary_output_2_accuracy: 0.7401 - val_loss: 0.1642 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0381 - val_auxilliary_output_2_loss: 0.0362 - val_output_accuracy: 0.9000 - val_auxilliary_output_1_accuracy: 0.7225 - val_auxilliary_output_2_accuracy: 0.7329
# Epoch 22/25
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.009216.
# 1563/1563 [==============================] - 200s 128ms/step - loss: 0.1624 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0379 - auxilliary_output_2_loss: 0.0344 - output_accuracy: 0.0198 - auxilliary_output_1_accuracy: 0.7266 - auxilliary_output_2_accuracy: 0.7540 - val_loss: 0.1635 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0370 - val_auxilliary_output_2_loss: 0.0365 - val_output_accuracy: 0.0000e+00 - val_auxilliary_output_1_accuracy: 0.7318 - val_auxilliary_output_2_accuracy: 0.7336
# Epoch 23/25
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.009216.
# 1563/1563 [==============================] - 191s 122ms/step - loss: 0.1593 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0366 - auxilliary_output_2_loss: 0.0328 - output_accuracy: 0.0233 - auxilliary_output_1_accuracy: 0.7355 - auxilliary_output_2_accuracy: 0.7666 - val_loss: 0.1591 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0352 - val_auxilliary_output_2_loss: 0.0339 - val_output_accuracy: 0.0000e+00 - val_auxilliary_output_1_accuracy: 0.7473 - val_auxilliary_output_2_accuracy: 0.7551
# Epoch 24/25
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.008847359999999999.
# 1563/1563 [==============================] - 191s 122ms/step - loss: 0.1570 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0354 - auxilliary_output_2_loss: 0.0316 - output_accuracy: 0.0423 - auxilliary_output_1_accuracy: 0.7455 - auxilliary_output_2_accuracy: 0.7739 - val_loss: 0.1599 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0357 - val_auxilliary_output_2_loss: 0.0342 - val_output_accuracy: 0.0000e+00 - val_auxilliary_output_1_accuracy: 0.7428 - val_auxilliary_output_2_accuracy: 0.7519
# Epoch 25/25
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.008847359999999999.
# 1563/1563 [==============================] - 191s 122ms/step - loss: 0.1559 - output_loss: 0.0900 - auxilliary_output_1_loss: 0.0349 - auxilliary_output_2_loss: 0.0309 - output_accuracy: 7.0024e-04 - auxilliary_output_1_accuracy: 0.7486 - auxilliary_output_2_accuracy: 0.7788 - val_loss: 0.1558 - val_output_loss: 0.0900 - val_auxilliary_output_1_loss: 0.0338 - val_auxilliary_output_2_loss: 0.0320 - val_output_accuracy: 0.0000e+00 - val_auxilliary_output_1_accuracy: 0.7541 - val_auxilliary_output_2_accuracy: 0.7719
