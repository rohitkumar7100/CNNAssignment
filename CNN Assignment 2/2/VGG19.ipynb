# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
ROOT = "/content/drive/MyDrive/Collab notebook/VGG_Flower"
os.chdir(ROOT)
assert ROOT == os.getcwd()

# %%
from keras.models import Sequential
import keras
from keras.layers import Conv2D, AveragePooling2D, Flatten, Dense, Activation, MaxPool2D, BatchNormalization, Dropout, ZeroPadding2D

# %%
vgg_19 = Sequential()

# first block
vgg_19.add(Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same',input_shape=(224,224, 3)))
vgg_19.add(Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(MaxPool2D((2,2), strides=(2,2)))

# second block
vgg_19.add(Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(MaxPool2D((2,2), strides=(2,2)))

# third block
vgg_19.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(MaxPool2D((2,2), strides=(2,2)))

# forth block
vgg_19.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(MaxPool2D((2,2), strides=(2,2)))

# fifth block
vgg_19.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(MaxPool2D((2,2), strides=(2,2)))

# seventh block (classifier)
vgg_19.add(Flatten())
vgg_19.add(Dense(4096, activation='relu'))
vgg_19.add(Dropout(0.5))
vgg_19.add(Dense(4096, activation='relu'))
vgg_19.add(Dropout(0.5))
vgg_19.add(Dense(5, activation='softmax'))

vgg_19.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4096)              102764544
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 20485
# =================================================================
# Total params: 139,590,725
# Trainable params: 139,590,725
# Non-trainable params: 0
# _________________________________________________________________

# %%
vgg_19.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                  shear_range=0.2,
                                  zoom_range=0.2,
                                  horizontal_flip=True)

# %%
training_set = train_datagen.flow_from_directory('archive/flowers',
                                                target_size=(224,224),
                                                class_mode='categorical')
# Out:
# Found 4323 images belonging to 5 classes.

# %%
model = vgg_19.fit_generator(training_set,steps_per_epoch=50,  # 2000 images = batch_size * steps
      epochs=30,verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/30
# 50/50 [==============================] - 831s 17s/step - loss: 2.5075 - accuracy: 0.2193
# Epoch 2/30
# 50/50 [==============================] - 910s 18s/step - loss: 1.6000 - accuracy: 0.2382
# Epoch 3/30
# 50/50 [==============================] - 669s 13s/step - loss: 1.6000 - accuracy: 0.2395
# Epoch 4/30
# 50/50 [==============================] - 45s 907ms/step - loss: 1.5930 - accuracy: 0.2580
# Epoch 5/30
# 50/50 [==============================] - 45s 907ms/step - loss: 1.6052 - accuracy: 0.2330
# Epoch 6/30
# 50/50 [==============================] - 45s 900ms/step - loss: 1.6035 - accuracy: 0.2310
# Epoch 7/30
# 50/50 [==============================] - 45s 907ms/step - loss: 1.6064 - accuracy: 0.2300
# Epoch 8/30
# 50/50 [==============================] - 45s 908ms/step - loss: 1.5959 - accuracy: 0.2330
# Epoch 9/30
# 50/50 [==============================] - 45s 900ms/step - loss: 1.5937 - accuracy: 0.2625
# Epoch 10/30
# 50/50 [==============================] - 45s 908ms/step - loss: 1.5970 - accuracy: 0.2595
# Epoch 11/30
# 50/50 [==============================] - 45s 900ms/step - loss: 1.5987 - accuracy: 0.2545
# Epoch 12/30
# 50/50 [==============================] - 45s 909ms/step - loss: 1.5953 - accuracy: 0.2424
# Epoch 13/30
# 50/50 [==============================] - 45s 908ms/step - loss: 1.5962 - accuracy: 0.2366
# Epoch 14/30
# 50/50 [==============================] - 45s 901ms/step - loss: 1.5973 - accuracy: 0.2515
# Epoch 15/30
# 50/50 [==============================] - 45s 908ms/step - loss: 1.6049 - accuracy: 0.2266
# Epoch 16/30
# 50/50 [==============================] - 45s 907ms/step - loss: 1.5944 - accuracy: 0.2437
# Epoch 17/30
# 50/50 [==============================] - 45s 900ms/step - loss: 1.6043 - accuracy: 0.2453
# Epoch 18/30
# 50/50 [==============================] - 45s 908ms/step - loss: 1.6057 - accuracy: 0.2231
# Epoch 19/30
# 50/50 [==============================] - 45s 907ms/step - loss: 1.5944 - accuracy: 0.2623
# Epoch 20/30
# 50/50 [==============================] - 45s 900ms/step - loss: 1.6105 - accuracy: 0.2319
# Epoch 21/30
# 50/50 [==============================] - 45s 908ms/step - loss: 1.5961 - accuracy: 0.2423
# Epoch 22/30
# 50/50 [==============================] - 45s 900ms/step - loss: 1.6009 - accuracy: 0.2293
# Epoch 23/30
# 50/50 [==============================] - 45s 907ms/step - loss: 1.5899 - accuracy: 0.2701
# Epoch 24/30
# 50/50 [==============================] - 45s 907ms/step - loss: 1.5999 - accuracy: 0.2460
# Epoch 25/30
# 50/50 [==============================] - 45s 902ms/step - loss: 1.6029 - accuracy: 0.2423
# Epoch 26/30
# 50/50 [==============================] - 45s 908ms/step - loss: 1.6010 - accuracy: 0.2290
# Epoch 27/30
# 50/50 [==============================] - 45s 905ms/step - loss: 1.6002 - accuracy: 0.2469
# Epoch 28/30
# 50/50 [==============================] - 45s 900ms/step - loss: 1.6037 - accuracy: 0.2307
# Epoch 29/30
# 50/50 [==============================] - 45s 908ms/step - loss: 1.6027 - accuracy: 0.2445
# Epoch 30/30
# 50/50 [==============================] - 45s 900ms/step - loss: 1.5978 - accuracy: 0.2510
