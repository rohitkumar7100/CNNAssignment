# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
ROOT = "/content/drive/MyDrive/Collab notebook/VGG_Flower"
os.chdir(ROOT)
assert ROOT == os.getcwd()

# %%
from keras.models import Sequential
import keras
from keras.layers import Conv2D, AveragePooling2D, Flatten, Dense, Activation, MaxPool2D, BatchNormalization, Dropout, ZeroPadding2D

# %%
model = Sequential()

# first block
model.add(Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same',input_shape=(224,224, 3)))
model.add(Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

# second block
model.add(Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

# third block
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

# forth block
model.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

# fifth block
model.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

# sixth block (classifier)
model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(5, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              102764544
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 20485
# =================================================================
# Total params: 134,281,029
# Trainable params: 134,281,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                  shear_range=0.2,
                                  zoom_range=0.2,
                                  horizontal_flip=True)

# %%
training_set = train_datagen.flow_from_directory('archive/flowers',
                                                target_size=(224,224),
                                                class_mode='categorical')
# Out:
# Found 4323 images belonging to 5 classes.

# %%
model_final = model.fit_generator(training_set,steps_per_epoch=50,  # 2000 images = batch_size * steps
      epochs=30,verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/30
# 50/50 [==============================] - 451s 8s/step - loss: 0.6792 - accuracy: 0.2406
# Epoch 2/30
# 50/50 [==============================] - 417s 8s/step - loss: 0.5022 - accuracy: 0.2201
# Epoch 3/30
# 50/50 [==============================] - 304s 6s/step - loss: 0.5026 - accuracy: 0.2387
# Epoch 4/30
# 50/50 [==============================] - 33s 664ms/step - loss: 0.5012 - accuracy: 0.2376
# Epoch 5/30
# 50/50 [==============================] - 33s 661ms/step - loss: 0.5020 - accuracy: 0.2324
# Epoch 6/30
# 50/50 [==============================] - 33s 662ms/step - loss: 0.5000 - accuracy: 0.2224
# Epoch 7/30
# 50/50 [==============================] - 33s 658ms/step - loss: 0.5015 - accuracy: 0.2116
# Epoch 8/30
# 50/50 [==============================] - 33s 659ms/step - loss: 0.4962 - accuracy: 0.2588
# Epoch 9/30
# 50/50 [==============================] - 33s 651ms/step - loss: 0.5009 - accuracy: 0.2233
# Epoch 10/30
# 50/50 [==============================] - 33s 656ms/step - loss: 0.5023 - accuracy: 0.2127
# Epoch 11/30
# 50/50 [==============================] - 33s 656ms/step - loss: 0.5006 - accuracy: 0.2166
# Epoch 12/30
# 50/50 [==============================] - 33s 660ms/step - loss: 0.4999 - accuracy: 0.2464
# Epoch 13/30
# 50/50 [==============================] - 33s 660ms/step - loss: 0.5021 - accuracy: 0.2214
# Epoch 14/30
# 50/50 [==============================] - 32s 650ms/step - loss: 0.4979 - accuracy: 0.2495
# Epoch 15/30
# 50/50 [==============================] - 33s 667ms/step - loss: 0.4996 - accuracy: 0.2335
# Epoch 16/30
# 50/50 [==============================] - 33s 661ms/step - loss: 0.4998 - accuracy: 0.2427
# Epoch 17/30
# 50/50 [==============================] - 33s 657ms/step - loss: 0.5025 - accuracy: 0.2154
# Epoch 18/30
# 50/50 [==============================] - 33s 668ms/step - loss: 0.5003 - accuracy: 0.2338
# Epoch 19/30
# 50/50 [==============================] - 33s 662ms/step - loss: 0.4981 - accuracy: 0.2666
# Epoch 20/30
# 50/50 [==============================] - 33s 658ms/step - loss: 0.5008 - accuracy: 0.2136
# Epoch 21/30
# 50/50 [==============================] - 33s 662ms/step - loss: 0.4993 - accuracy: 0.2489
# Epoch 22/30
# 50/50 [==============================] - 33s 657ms/step - loss: 0.4971 - accuracy: 0.2570
# Epoch 23/30
# 50/50 [==============================] - 33s 659ms/step - loss: 0.5002 - accuracy: 0.2382
# Epoch 24/30
# 50/50 [==============================] - 33s 662ms/step - loss: 0.5003 - accuracy: 0.2397
# Epoch 25/30
# 50/50 [==============================] - 32s 649ms/step - loss: 0.4976 - accuracy: 0.2453
# Epoch 26/30
# 50/50 [==============================] - 33s 658ms/step - loss: 0.5009 - accuracy: 0.2321
# Epoch 27/30
# 50/50 [==============================] - 33s 656ms/step - loss: 0.4992 - accuracy: 0.2295
# Epoch 28/30
# 50/50 [==============================] - 33s 653ms/step - loss: 0.4977 - accuracy: 0.2523
# Epoch 29/30
# 50/50 [==============================] - 33s 664ms/step - loss: 0.4993 - accuracy: 0.2541
# Epoch 30/30
# 50/50 [==============================] - 32s 649ms/step - loss: 0.4981 - accuracy: 0.2450
